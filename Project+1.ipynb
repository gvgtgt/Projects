# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv('Desktop/Data/air_reserve.csv')
df11 = pd.DataFrame(df1.visit_datetime.str.split(' ').tolist(),
                                  columns = ['visit_date','visit_time'])
#df11.head()
df2 = pd.merge(df1[['air_store_id']],df11,how='outer',left_index = True,right_index = True)

df2.head()
df12 = pd.DataFrame(df1.reserve_datetime.str.split(' ').tolist(),
                                  columns = ['reserve_date','reserve_time'])
#df11.head()
df13 = pd.merge(df2,df12,how='outer',left_index = True,right_index = True)
df13
df14 =  pd.merge(df13,df1[['reserve_visitors']],how='outer',left_index = True,right_index = True)
df14
# Out:
#                air_store_id  visit_date visit_time reserve_date reserve_time  \
# 0      air_877f79706adbfb06  2016-01-01   19:00:00   2016-01-01     16:00:00
# 1      air_db4b38ebe7a7ceff  2016-01-01   19:00:00   2016-01-01     19:00:00
# 2      air_db4b38ebe7a7ceff  2016-01-01   19:00:00   2016-01-01     19:00:00
# 3      air_877f79706adbfb06  2016-01-01   20:00:00   2016-01-01     16:00:00
# 4      air_db80363d35f10926  2016-01-01   20:00:00   2016-01-01     01:00:00
# 5      air_db80363d35f10926  2016-01-02   01:00:00   2016-01-01     16:00:00
# 6      air_db80363d35f10926  2016-01-02   01:00:00   2016-01-01     15:00:00
# 7      air_3bb99a1fe0583897  2016-01-02   16:00:00   2016-01-02     14:00:00
# 8      air_3bb99a1fe0583897  2016-01-02   16:00:00   2016-01-01     20:00:00
# 9      air_2b8b29ddfd35018e  2016-01-02   17:00:00   2016-01-02     17:00:00
# 10     air_6b15edd1b4fbb96a  2016-01-02   17:00:00   2016-01-01     22:00:00
# ...

# %% [markdown]
# df2 = pd.read_csv('Desktop/Data/air_store_info.csv')
# df2.head()

# %%
df4 = pd.read_csv('Desktop/Data/air_visit_data.csv')
df4
# Out:
#                 air_store_id  visit_date  visitors
# 0       air_ba937bf13d40fb24  2016-01-13        25
# 1       air_ba937bf13d40fb24  2016-01-14        32
# 2       air_ba937bf13d40fb24  2016-01-15        29
# 3       air_ba937bf13d40fb24  2016-01-16        22
# 4       air_ba937bf13d40fb24  2016-01-18         6
# 5       air_ba937bf13d40fb24  2016-01-19         9
# 6       air_ba937bf13d40fb24  2016-01-20        31
# 7       air_ba937bf13d40fb24  2016-01-21        21
# 8       air_ba937bf13d40fb24  2016-01-22        18
# 9       air_ba937bf13d40fb24  2016-01-23        26
# 10      air_ba937bf13d40fb24  2016-01-25        21
# 11      air_ba937bf13d40fb24  2016-01-26        11
# 12      air_ba937bf13d40fb24  2016-01-27        24
# 13      air_ba937bf13d40fb24  2016-01-28        21
# 14      air_ba937bf13d40fb24  2016-01-29        26
# 15      air_ba937bf13d40fb24  2016-01-30         6
# 16      air_ba937bf13d40fb24  2016-02-03        18
# ...

# %%
df3 = pd.read_csv('Desktop/Data/hpg_reserve.csv')
df3
# Out:
#                  hpg_store_id       visit_datetime     reserve_datetime  \
# 0        hpg_c63f6f42e088e50f  2016-01-01 11:00:00  2016-01-01 09:00:00
# 1        hpg_dac72789163a3f47  2016-01-01 13:00:00  2016-01-01 06:00:00
# 2        hpg_c8e24dcf51ca1eb5  2016-01-01 16:00:00  2016-01-01 14:00:00
# 3        hpg_24bb207e5fd49d4a  2016-01-01 17:00:00  2016-01-01 11:00:00
# 4        hpg_25291c542ebb3bc2  2016-01-01 17:00:00  2016-01-01 03:00:00
# 5        hpg_28bdf7a336ec6a7b  2016-01-01 17:00:00  2016-01-01 15:00:00
# 6        hpg_2a01a042bca04ad9  2016-01-01 17:00:00  2016-01-01 17:00:00
# 7        hpg_2a84dd9f4c140b82  2016-01-01 17:00:00  2016-01-01 15:00:00
# 8        hpg_2ad179871696901f  2016-01-01 17:00:00  2016-01-01 13:00:00
# 9        hpg_2c1d989eedb0ff83  2016-01-01 17:00:00  2016-01-01 15:00:00
# 10       hpg_33ec1499d6b13141  2016-01-01 17:00:00  2016-01-01 15:00:00
# 11       hpg_3db9d09c5f93950a  2016-01-01 17:00:00  2016-01-01 16:00:00
# ...

# %%
df1
# Out:
#                air_store_id       visit_datetime     reserve_datetime  \
# 0      air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 1      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 2      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 3      air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 4      air_db80363d35f10926  2016-01-01 20:00:00  2016-01-01 01:00:00
# 5      air_db80363d35f10926  2016-01-02 01:00:00  2016-01-01 16:00:00
# 6      air_db80363d35f10926  2016-01-02 01:00:00  2016-01-01 15:00:00
# 7      air_3bb99a1fe0583897  2016-01-02 16:00:00  2016-01-02 14:00:00
# 8      air_3bb99a1fe0583897  2016-01-02 16:00:00  2016-01-01 20:00:00
# 9      air_2b8b29ddfd35018e  2016-01-02 17:00:00  2016-01-02 17:00:00
# 10     air_6b15edd1b4fbb96a  2016-01-02 17:00:00  2016-01-01 22:00:00
# 11     air_6b15edd1b4fbb96a  2016-01-02 17:00:00  2016-01-01 12:00:00
# ...

# %%
# Out:
# [17,
#  128,
#  53,
#  122,
#  76,
#  159,
#  159,
#  488,
#  507,
#  348,
#  160,
#  198,
#  388,
#  278,
#  544,
#  625,
#  287,
#  247,
#  312,
#  340,
#  366,
#  593,
#  685,
#  255,
#  306,
#  412,
#  379,
#  371,
#  664,
#  703,
#  165,
#  197,
#  207,
#  250,
#  274,
#  649,
#  667,
#  189,
#  249,
#  310,
#  680,
#  258,
#  627,
#  696,
#  232,
#  270,
#  292,
#  273,
#  329,
#  606,
#  619,
#  302,
#  146,
#  369,
#  408,
#  406,
#  679,
#  814,
#  294,
#  287,
#  300,
#  327,
#  284,
#  609,
#  688,
#  280,
#  245,
#  351,
#  423,
#  407,
#  852,
#  761,
#  386,
#  426,
#  426,
#  424,
#  513,
#  1030,
#  876,
#  753,
#  338,
#  577,
#  542,
#  572,
#  1200,
#  1037,
#  380,
#  587,
#  529,
#  608,
#  340,
#  375,
#  515,
#  239,
#  230,
#  357,
#  323,
#  396,
#  718,
#  721,
#  299,
#  267,
#  390,
#  342,
#  381,
#  735,
#  691,
#  275,
#  258,
#  375,
#  438,
#  350,
#  913,
#  754,
#  280,
#  346,
#  442,
#  487,
#  733,
#  548,
#  633,
#  349,
#  320,
#  533,
#  444,
# ...

# %%
df14 = df14.set_index(['visit_date','air_store_id','visit_time'])
df14
# Out:
#                                            reserve_date reserve_time  \
# visit_date air_store_id         visit_time
# 2016-01-01 air_877f79706adbfb06 19:00:00     2016-01-01     16:00:00
#            air_db4b38ebe7a7ceff 19:00:00     2016-01-01     19:00:00
#                                 19:00:00     2016-01-01     19:00:00
#            air_877f79706adbfb06 20:00:00     2016-01-01     16:00:00
#            air_db80363d35f10926 20:00:00     2016-01-01     01:00:00
# 2016-01-02 air_db80363d35f10926 01:00:00     2016-01-01     16:00:00
#                                 01:00:00     2016-01-01     15:00:00
#            air_3bb99a1fe0583897 16:00:00     2016-01-02     14:00:00
#                                 16:00:00     2016-01-01     20:00:00
#            air_2b8b29ddfd35018e 17:00:00     2016-01-02     17:00:00
#            air_6b15edd1b4fbb96a 17:00:00     2016-01-01     22:00:00
#                                 17:00:00     2016-01-01     12:00:00
# ...

# %%
df14.iloc[:5][1:15]
# Out:
#                                            reserve_date reserve_time  \
# visit_date air_store_id         visit_time
# 2016-01-01 air_db4b38ebe7a7ceff 19:00:00     2016-01-01     19:00:00
#                                 19:00:00     2016-01-01     19:00:00
#            air_877f79706adbfb06 20:00:00     2016-01-01     16:00:00
#            air_db80363d35f10926 20:00:00     2016-01-01     01:00:00
#
#                                             reserve_visitors
# visit_date air_store_id         visit_time
# 2016-01-01 air_db4b38ebe7a7ceff 19:00:00                   3
#                                 19:00:00                   6
#            air_877f79706adbfb06 20:00:00                   2
#            air_db80363d35f10926 20:00:00                   5
